# %% [markdown]
# # Project 3: Detecting Credit Card Fraud
#
# Dataset is from [kaggle](https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud)
#
# ### Dataset Overview:
# * Columns:
#     * Time (float)
#     * V1 - V28 (float)
#     * Amount (float)
#     * class (int)
# * About the dataset:
#     * this data contains transactional information (numerical input variables as a result of PCA transformation) from credit cards in September 2013 in EU
#     * the dataset contains 492 out of 284,807 transaction in 2 days. Very unbalanced with only
#     0.172% of positive cases
#
# ## 1. Importing Libraries and Data Mining

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 2. Importing and Reading the Dataset

# %%
data = pd.read_csv('/Users/johnnysin/Downloads/creditcard.csv')
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# data information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
# missing value in the dataset?
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## 2. Distribution of Normal and Fraud transactions

# %%
data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# Here we see that the dataset is skewed with significantly lower positive values (fraud cases)

# %%
# separating the data
normal = data[data.Class==0]
fraud = data[data.Class==1]

# %%
normal.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %% [markdown]
# ## 3. Creating a new dataset
# ##### *choosing 492 random transactions from the normal dataset*

# %%
normal_sample = normal.sample(n=492)

# %%
normal_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 237705  149360.0 -0.246109  1.194286 -0.912552 -0.421167  0.886964 -1.165933
# 168910  119436.0 -4.222861 -2.125824 -3.610840 -0.686268  1.559709 -2.227341
# 200867  133614.0  0.101036  0.880332  0.834792  2.666703  1.335936  0.904359
# 163482  115971.0  2.262538 -1.745051 -0.334884 -1.650563 -1.595966  0.311496
# 248052  153784.0  2.096868 -1.576352 -1.090182 -1.641218  0.747902  4.381270
# ...          ...       ...       ...       ...       ...       ...       ...
# 274326  165959.0  0.497891 -3.579021 -2.202132 -0.041862 -1.558152 -0.947046
# 35841    38290.0  1.258509  0.119476  0.476111  0.639000 -0.641945 -1.036544
# 252060  155633.0 -0.173904  0.273750  0.777996 -0.557276  0.645484  1.586147
# 154400  101419.0  1.720521 -0.347084 -0.271200  1.861305 -0.372049 -0.152705
# 187401  127518.0 -0.766810  0.599443  1.620162 -0.427501 -0.123430 -0.074357
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 237705  1.027895 -0.131679 -0.250516  ...  0.481089  1.593507 -0.134918
# 168910  0.967344 -0.325003 -0.584377  ... -0.786836  1.263283  1.629390
# 200867  0.225514  0.261193 -1.091926  ... -0.062196 -0.251843  0.358570
# 163482 -1.910591  0.169614 -0.400143  ... -0.197128 -0.105322  0.295715
# 248052 -2.271850  1.244104  0.857574  ...  0.133372  0.597006  0.280175
# ...          ...       ...       ...  ...       ...       ...       ...
# 274326  0.835022 -0.562582 -0.336945  ...  0.493985 -0.552604 -0.552775
# 35841  -0.059790 -0.103594  0.317235  ... -0.277918 -0.891559  0.158060
# 252060 -0.142234  0.561740  0.533848  ...  0.499599  1.731249  0.034243
# 154400 -0.160627 -0.144238  2.378427  ... -0.601098 -1.401193  0.344930
# 187401  0.375760 -0.163725  0.781066  ...  0.267602  1.196742 -0.291798
#
#              V24       V25       V26       V27       V28  Amount  Class
# 237705  1.104093 -0.797107  0.586616 -0.210922 -0.009845    5.95      0
# 168910  0.732590 -0.591560  0.702508  0.590679 -0.579535   77.60      0
# 200867 -0.098604 -1.474830 -0.586392  0.202270  0.192468    4.57      0
# 163482  0.031698 -0.468493 -0.237298  0.053180 -0.028969   28.00      0
# 248052  0.737922 -0.302255 -0.168415  0.082647 -0.044151    1.00      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 274326  0.008024 -0.413355 -0.418322 -0.203340  0.091928  899.00      0
# 35841   0.331059  0.156361  0.100524 -0.040847  0.015202    1.98      0
# 252060 -1.380754 -1.434138 -0.254201  0.240537  0.264270    9.47      0
# 154400 -0.210332 -0.371421 -1.149790  0.013549 -0.017576  117.99      0
# 187401  0.102430 -0.475356 -0.327323 -0.810914 -0.558856    9.99      0
#
# [492 rows x 31 columns]

# %% [markdown]
# Here now we match the number of rows with the positive values (fraud data)

# %%
new_data = pd.concat([normal_sample, fraud], axis=0)
new_data.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     984.000000  984.000000  984.000000  984.000000  984.000000
# mean    89533.723577   -2.357206    1.791793   -3.553761    2.272277
# std     47927.392010    5.537376    3.731543    6.208962    3.192536
# min       406.000000  -30.552380  -16.417395  -31.103685   -3.099974
# 25%     48362.500000   -2.867222   -0.182297   -5.146620   -0.155495
# 50%     84204.000000   -0.719808    1.003518   -1.422658    1.315483
# 75%    135991.250000    1.056312    2.814266    0.301433    4.235631
# max    172087.000000    2.354755   22.057729    3.528608   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  984.000000  984.000000  984.000000  984.000000  984.000000  ...
# mean    -1.595310   -0.694789   -2.769727    0.297267   -1.271739  ...
# std      4.303719    1.840402    5.945396    4.877834    2.323035  ...
# min    -27.752964   -6.406267  -43.557242  -41.044261  -13.434066  ...
# 25%     -1.845482   -1.599839   -3.105154   -0.192932   -2.298358  ...
# 50%     -0.421690   -0.639088   -0.687471    0.136416   -0.697871  ...
# 75%      0.456639    0.085101    0.258779    0.885597    0.151853  ...
# max     11.095089   18.072031   28.504065   20.007208    4.536487  ...
#
#               V21         V22         V23         V24         V25         V26  \
# count  984.000000  984.000000  984.000000  984.000000  984.000000  984.000000
# mean     0.344820    0.009189   -0.037797   -0.054524    0.006981    0.028873
# std      2.795788    1.181572    1.245850    0.564618    0.685135    0.457613
# min    -22.797604   -8.887017  -19.254328   -2.375790   -4.781606   -1.158898
# 25%     -0.172669   -0.543407   -0.243526   -0.405936   -0.325570   -0.265555
# 50%      0.159252    0.035816   -0.033769    0.008012    0.039665   -0.006892
# 75%      0.644249    0.594179    0.193367    0.367402    0.389374    0.282435
# max     27.202839    8.361985    5.466230    1.550407    2.208209    2.745261
#
#               V27         V28       Amount       Class
# count  984.000000  984.000000   984.000000  984.000000
# mean     0.099728    0.042734   113.099400    0.500000
# std      1.088605    0.470901   358.791967    0.500254
# min     -7.263482   -4.009839     0.000000    0.000000
# 25%     -0.048206   -0.053064     1.520000    0.000000
# 50%      0.053886    0.031730    18.755000    0.500000
# 75%      0.459847    0.219111    99.990000    1.000000
# max     12.152401    4.585234  8790.260000    1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# ### Splitting the "new" Dataset

# %%
X=new_data.drop(columns = 'Class', axis = 1)
y=new_data['Class']

# %%
y
# Out:
# 237705    0
# 168910    0
# 200867    0
# 163482    0
# 248052    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size = 0.2, stratify=y, random_state = 42)

# %%
print(X_train, X_test, Y_train, Y_test)
# Out:
#             Time         V1         V2         V3        V4         V5  \
# 49613    44135.0   0.634838  -1.143511   1.808769  1.682620  -1.492012
# 27941    34777.0   1.183732   0.040298   1.060949  2.685373  -0.408925
# 56703    47545.0   1.176716   0.557091  -0.490800  0.756424   0.249192
# 150684   93888.0 -10.040631   6.139183 -12.972972  7.740555  -8.684705
# 6882      8808.0  -4.617217   1.695694  -3.114372  4.328199  -1.873257
# ...          ...        ...        ...        ...       ...        ...
# 39183    39729.0  -0.964567  -1.643541  -0.187727  1.158253  -2.458336
# 205716  135880.0  -5.472082  -3.952467  -0.927776 -1.231708  -0.711065
# 143335   85285.0  -6.713407   3.921104  -9.746678  5.148263  -5.151563
# 273206  165478.0  -1.913675   1.678326  -0.949002 -0.699536   0.211417
# 17317    28625.0 -27.848181  15.598193 -28.923756  6.418442 -20.346228
#
#               V6         V7         V8        V9  ...       V20       V21  \
# 49613   1.488588  -1.170296   0.607617  1.625668  ...  0.212626  0.278232
# 27941   0.944072  -0.688007   0.317599  0.659124  ... -0.210987 -0.055367
# 56703  -0.781871   0.228750  -0.040840 -0.432111  ... -0.102772 -0.062166
# 150684 -3.837429 -11.907702   5.833273 -5.731054  ... -0.082275  2.823431
# 6882   -0.989908  -4.577265   0.472216  0.472017  ... -0.039046  0.481830
# ...          ...        ...        ...       ...  ...       ...       ...
# 39183   0.852222   2.785163  -0.303609  0.940006  ...  1.784449  0.447180
# 205716 -0.800448   1.292087   0.596580  0.602532  ...  0.965118 -0.249593
# 143335 -2.099389  -5.937767   3.578780 -4.684952  ...  0.135711  0.954272
# 273206  0.419873   0.028026   1.393590 -0.419864  ... -0.533652  0.054072
# 17317  -4.828202 -19.210896  18.329406 -3.668735  ...  1.697856  1.802149
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 49613   0.931415 -0.309858  0.109688  0.425786 -0.123203  0.103300  0.060851
# 27941   0.166345 -0.242526 -0.590571  0.722539  0.278250  0.041790  0.014905
# 56703  -0.128168 -0.040176  0.110040  0.437891  0.368809 -0.018287  0.031173
# 150684  1.153005 -0.567343  0.843012  0.549938  0.113892 -0.307375  0.061631
# 6882    0.146023  0.117039 -0.217565 -0.138776 -0.424453 -1.002041  0.890780
# ...          ...       ...       ...       ...       ...       ...       ...
# 39183   0.536204  1.634061  0.203839  0.218749 -0.221886 -0.308555 -0.164500
# 205716 -1.872699 -0.451197 -0.564874  0.513095  0.142562  0.330945 -0.702254
# 143335 -0.451086  0.127214 -0.339450  0.394096  1.075295  1.649906 -0.394905
# 273206  0.000378 -0.038832 -1.126677 -0.091362 -0.011045 -0.439448 -0.097121
# 17317  -2.062934 -1.269843  0.165409  1.999499 -0.211059  1.324809  0.388090
#
#         Amount
# 49613   195.00
# 27941     0.00
# 56703     0.76
# 150684    1.00
# 6882      1.10
# ...        ...
# 39183   776.83
# 205716  582.85
# 143335  252.92
# 273206   56.08
# 17317    99.99
#
# [787 rows x 30 columns]             Time        V1        V2        V3        V4        V5        V6  \
# 230076  146179.0 -0.067672  4.251181 -6.540388  7.283657  0.513541 -2.635066
# 262826  160665.0 -0.417340  4.700055 -7.521767  7.671884  0.260821 -2.646693
# 92349    63891.0  1.202044  0.147537  0.602971  0.560877 -0.592571 -0.803792
# 30314    35866.0 -2.044489  3.368306 -3.937111  5.623120 -3.079232 -1.253474
# 119255   75385.0 -1.358121  1.214912 -1.230980 -2.372590  1.736635  2.909499
# ...          ...       ...       ...       ...       ...       ...       ...
# 99051    66938.0 -0.317019 -0.573477  2.137421 -0.790887 -0.932454  0.319484
# 6472      7740.0  1.023874  2.001485 -4.769752  3.819195 -1.271754 -1.734662
# 95538    65362.0  0.974371 -1.260500  1.582824  1.167159 -1.817782  0.949146
# 52466    45463.0 -1.476893  2.122314 -1.229470  1.201849 -0.343264 -1.317704
# 243319  151884.0  0.093319  0.977059 -0.331880 -0.624988  0.888892 -0.592453
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 230076 -1.865911  0.780272 -3.868248  ...  0.519404  0.415437 -0.469938
# 262826 -2.854432  0.958783 -4.588536  ...  0.832035  0.622200 -0.437708
# 92349  -0.089756 -0.026987 -0.109626  ... -0.138802 -0.201231 -0.658804
# 30314  -5.778880  1.707428 -4.467103  ...  1.112028  1.483594  0.834311
# 119255 -0.577526  1.709053 -0.247406  ...  0.022557 -0.054013 -0.510155
# ...          ...       ...       ...  ...       ...       ...       ...
# 99051  -0.436014  0.155134 -1.007599  ...  0.420417  0.561066  1.520717
# 6472   -3.059245  0.889805  0.415382  ...  0.204138  0.343283 -0.054196
# 95538  -1.382103  0.465607  0.770596  ... -0.498786 -0.423865 -0.506222
# 52466  -1.528142 -0.620953 -1.213040  ...  0.276893  1.186036 -0.040215
# 243319  0.865697  0.036681 -0.291863  ...  0.016342 -0.283002 -0.711688
#
#              V23       V24       V25       V26       V27       V28  Amount
# 230076  0.007128 -0.388147 -0.493398  0.466468  0.566370  0.262990    0.77
# 262826 -0.090358 -0.742802 -0.312361  0.502575  0.821390  0.372379    0.77
# 92349   0.158567  0.508836  0.133402  0.067080 -0.037782  0.009258    1.98
# 30314  -0.148486  0.001669 -0.038996  0.389526  1.300236  0.549940    7.61
# 119255  0.009968  1.036694  0.031926  0.777566 -0.092426  0.011989    8.76
# ...          ...       ...       ...       ...       ...       ...     ...
# 99051  -0.001153  0.017518 -0.532969  0.009512 -0.006939 -0.079348   79.98
# 6472    0.709654 -0.372216 -2.032068  0.366778  0.395171  0.020206    1.00
# 95538  -0.027914  0.031625  0.281245 -0.252867  0.118275  0.052917  106.90
# 52466  -0.238930  0.110144  0.045418 -0.569232  0.481019 -0.047555    1.00
# 243319  0.102199  0.656228 -0.473777  0.087180  0.217483  0.075203    3.59
#
# [197 rows x 30 columns] 49613     0
# 27941     0
# 56703     1
# 150684    1
# 6882      1
#          ..
# 39183     1
# 205716    0
# 143335    1
# 273206    0
# 17317     1
# Name: Class, Length: 787, dtype: int64 230076    1
# 262826    1
# 92349     0
# 30314     1
# 119255    0
#          ..
# 99051     0
# 6472      1
# 95538     0
# 52466     1
# 243319    0
# Name: Class, Length: 197, dtype: int64

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_predict = model.predict(X_test)

# %%
acc = accuracy_score(Y_test, y_predict)
print(f'The accuracy of the Logistic Regression model is {acc}')
# Out:
# The accuracy of the Logistic Regression model is 0.9644670050761421
