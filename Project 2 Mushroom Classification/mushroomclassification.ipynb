# %% [markdown]
# # Project 2: Mushroom Classification
# ### Looking at the Mushroom dataset to figure out which of the class is edible vs poisonous
# ### Dataset Information:
# * Classes: Edible (e), Poisonous (p)
# * cap-shape = bell (b), conical (c), convex (x), flat (f), knobbed (k) sunken (s)
# * cap-surface = fibrous (f), grooves (g), scaly (y), smooth (s)
# * cap-color = brown (n), buff (b), cinnamon (c), gray (g), green (r), pink (p), purple (u), red (e), white (w), yellow *y(
# * bruises = bruises (t) no bruises (f)
# * odor = almond (a), anise (l), creosote (c), fishy (y), foul (f), musty (m), none (n), pungent (p), spicy (s)
# * gill-attachment = attached (a), descending (d), free (f), notched (n)
# * etc.

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC

# %% [markdown]
# ## Looking into the Dataset

# %%
mush = pd.read_csv('mushrooms.csv')
mush.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# ## Data Preprocessing-Label Encoding

# %%
mapping = list()
encoder = preprocessing.LabelEncoder()

#for every feature we will transform the values into an integer

for col in range(len(mush.columns)):
    mush[mush.columns[col]] = encoder.fit_transform(mush[mush.columns[col]])
    mapping_dict={index:label for index,label in enumerate(encoder.classes_)}
    mapping.append(mapping_dict)

# %%
mapping
# Out:
# [{0: 'e', 1: 'p'},
#  {0: 'b', 1: 'c', 2: 'f', 3: 'k', 4: 's', 5: 'x'},
#  {0: 'f', 1: 'g', 2: 's', 3: 'y'},
#  {0: 'b',
#   1: 'c',
#   2: 'e',
#   3: 'g',
#   4: 'n',
#   5: 'p',
#   6: 'r',
#   7: 'u',
#   8: 'w',
#   9: 'y'},
#  {0: 'f', 1: 't'},
#  {0: 'a', 1: 'c', 2: 'f', 3: 'l', 4: 'm', 5: 'n', 6: 'p', 7: 's', 8: 'y'},
#  {0: 'a', 1: 'f'},
#  {0: 'c', 1: 'w'},
#  {0: 'b', 1: 'n'},
#  {0: 'b',
#   1: 'e',
#   2: 'g',
#   3: 'h',
#   4: 'k',
#   5: 'n',
#   6: 'o',
#   7: 'p',
#   8: 'r',
#   9: 'u',
#   10: 'w',
#   11: 'y'},
#  {0: 'e', 1: 't'},
#  {0: '?', 1: 'b', 2: 'c', 3: 'e', 4: 'r'},
#  {0: 'f', 1: 'k', 2: 's', 3: 'y'},
#  {0: 'f', 1: 'k', 2: 's', 3: 'y'},
#  {0: 'b', 1: 'c', 2: 'e', 3: 'g', 4: 'n', 5: 'o', 6: 'p', 7: 'w', 8: 'y'},
#  {0: 'b', 1: 'c', 2: 'e', 3: 'g', 4: 'n', 5: 'o', 6: 'p', 7: 'w', 8: 'y'},
#  {0: 'p'},
#  {0: 'n', 1: 'o', 2: 'w', 3: 'y'},
#  {0: 'n', 1: 'o', 2: 't'},
#  {0: 'e', 1: 'f', 2: 'l', 3: 'n', 4: 'p'},
# ...

# %% [markdown]
# ## Splitting the Data into X and Y

# %%
X = mush.drop('class', axis=1)
Y = mush['class']

# %%
X
# Out:
#       cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0             5            2          4        1     6                1
# 1             5            2          9        1     0                1
# 2             0            2          8        1     3                1
# 3             5            3          8        1     6                1
# 4             5            2          3        0     5                1
# ...         ...          ...        ...      ...   ...              ...
# 8119          3            2          4        0     5                0
# 8120          5            2          4        0     5                0
# 8121          2            2          4        0     5                0
# 8122          3            3          4        0     8                1
# 8123          5            2          4        0     5                0
#
#       gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# ...

# %%
Y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int64

# %%
# normalizing the data
scaler= preprocessing.StandardScaler()

# %%
X = pd.DataFrame(scaler.fit_transform(X), columns = X.columns)
X
# Out:
#       cap-shape  cap-surface  cap-color   bruises      odor  gill-attachment  \
# 0      1.029712     0.140128  -0.198250  1.185917  0.881938         0.162896
# 1      1.029712     0.140128   1.765874  1.185917 -1.970316         0.162896
# 2     -2.087047     0.140128   1.373049  1.185917 -0.544189         0.162896
# 3      1.029712     0.953270   1.373049  1.185917  0.881938         0.162896
# 4      1.029712     0.140128  -0.591075 -0.843230  0.406562         0.162896
# ...         ...          ...        ...       ...       ...              ...
# 8119  -0.216992     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8120   1.029712     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8121  -0.840343     0.140128  -0.198250 -0.843230  0.406562        -6.138869
# 8122  -0.216992     0.953270  -0.198250 -0.843230  1.832689         0.162896
# 8123   1.029712     0.140128  -0.198250 -0.843230  0.406562        -6.138869
#
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2)

# %% [markdown]
# ## Model Selection and Score-Logistic Regression and SVM

# %%
lrmodel = LogisticRegression()
svmmodel=SVC(C=1.0,kernel='rbf')

# %%
lrmodel.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
svmmodel.fit(X_train,Y_train)
# Out:
# SVC()

# %%
print(f"Logistic Regression model has an accuracy score of {lrmodel.score(X_test, Y_test)}")
# Out:
# Logistic Regression model has an accuracy score of 0.9581538461538461

# %%
print(f"Support Vector Machine {lrmodel.score(X_test, Y_test)}")
# Out:
# Support Vector Machine 0.9581538461538461
